# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns
import bqplot as bq
import ipywidgets as widgets

# %matplotlib inline

# %%
electricity_intensity = pd.read_csv('./electricity_intensity.csv', index_col='Year')

# %%
plt.plot(electricity_intensity['Solar']);

# %%
plt.plot(electricity_intensity['Wind']);

# %%
plt.plot(electricity_intensity['Waste']);
